# %%
from google import genai
import os

# env vars
API_KEY = os.environ.get("API_KEY") # replace with your API key

marketing_prompt = """

You are a smart and friendly assistant.

A user wants help promoting their product. Your task is to collect or infer the following 3 essential details:

1. 🎯 **Target Audience** – Who is this product or service for? 
2. 🛍️ **Product Description** – What is the product?
3. 📈 **Campaign Goals** – What outcome do they want? (e.g., leads, downloads, awareness)

---

**Instructions:**

1. ✅ **Step 1 – Collect info**:  
   - Analyze what the user has already said.
   - If any of the 3 are missing, ask for only the missing parts.
   - Ask 1–2 things per turn. Keep it natural.

2. ✅ **Step 2 – If user give all 3 information**:
   - If all 3 are present (in one go), then perform what the user asked for

3. ✅ **Step 3 – Follow-up questions**:
   - If the user gives a follow-up prompt like:
     - “Can you generate infographics?”
     - “Can you change the tone?”
     - “Now write the caption.”
     - etc.
   - Use the previously gathered product info and last response.
   - Always respond with a helpful tone like a teammate.

---
If the user says something generic like “hi,” start by asking:  
➡️ “Hi! how can I help?”

Always sound warm, proactive, and collaborative.
---


"""
def marketing_handle(query):
    # initialize the model
    client = genai.Client(api_key = API_KEY)
    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents = query
    )
    return response.text

    # return {
    #     'statusCode': 200,
    #     'text': response.text
    # }

# %%
query = "Hi, I’m launching a productivity chatbot called FocusYes that helps remote workers stay on task using daily check-ins and gentle nudges. T" \
"he focus group is for remote workers such as developers, project managers. " \
"My main goal is to drive app downloads and get good feedback. i want to post it on Instagram. How should I promote it?"

res = marketing_handle(query)

# %%
print(res)
# Out:
# Okay, here's a comprehensive Instagram promotion strategy for your FocusYes chatbot, geared towards driving app downloads and collecting feedback from remote workers:
#
# **I.  Content Pillars & Themes:**
#
# *   **Focus & Productivity:** (Core Theme)
#     *   Tips for staying focused while working remotely.
#     *   Time management strategies for remote teams.
#     *   How to beat procrastination when you're at home.
#     *   "Work from Home Sanity" - How to avoid burnout.
#     *   Debunking common productivity myths.
#     *   Guest posts or quotes from productivity experts.
# *   **FocusYes Feature Highlights:** (Show, Don't Tell)
#     *   Short video demos of how the daily check-ins work.
#     *   Screenshots of the chatbot interface.
#     *   Explanations of how the "gentle nudges" work and are customizable.
#     *   Use cases for specific remote roles (developer, project manager).
#     *   Explain how the check-in is useful to build the habit of checking in with self.
# *   **Remote Work Lifestyle:** (Relatable & Engaging)
#     *   Share funny memes/quotes about remote work challenges.
#     *   "Workspace Inspiration" - Photos of aesthetically pleasing home offices.
#     *   "Remote Worker Wins" - Success stories or achievements from your target audience (sourced with permission).
#     *   Polls: "What's your biggest remote work challenge?"
#     *   Behind-the-scenes of the FocusYes team (humanize your brand).
# *   **Community Building:**
#     *   "Ask Me Anything" sessions with the FocusYes team.
#     *   Repost content from users who are using the product.
#     *   Run contests/giveaways to encourage user-generated content.
#     *   Highlight users of the app and their remote work setups/achievements.
# *   **Feedback and Improvement:**
#     *   Post and request for feedback, with a form linked in bio.
#     *   Thank you for the feedback, let us work on the update.
#
# **II.  Content Formats & Examples:**
#
# *   **Images:**
#     *   **Quotes:** Visually appealing quotes about focus, productivity, and remote work.
#         *   Example:  Image with the quote "The key is not to prioritize what's on your schedule, but to schedule your priorities."
#     *   **Infographics:** Simplified explanations of productivity techniques.
#         *   Example:  "The Pomodoro Technique: A Visual Guide."
#     *   **Screenshots:** Clean, attractive screenshots of the FocusYes chatbot in action.  Highlight specific features.
#         *   Example: Screenshot of the daily check-in interface, highlighting the ease of use.
#     *   **Behind-the-Scenes:**  Photos of your team working on FocusYes (humanize the brand).
#         *   Example: "A peek into our brainstorming session on new features for FocusYes! We're listening to your feedback!"
#     *   **User-Generated Content (UGC):**  Repost photos of users using FocusYes.
#
# *   **Videos/Reels:**
#     *   **Demos:**  Short, engaging video demos of FocusYes in action. Focus on solving a specific problem.
#         *   Example:  "Struggling to stay on task? See how FocusYes can help you break down your workday into manageable chunks."
#     *   **Tutorials:**  "How-to" videos explaining specific features.
#         *   Example:  "Customizing your FocusYes nudges to match your work style."
#     *   **Testimonials:**  Short video testimonials from satisfied users (incentivize with free access/feature requests).
#         *   Example: " [User Name] explains how FocusYes helped them overcome procrastination and meet their deadline."
#     *   **Storytelling:**  Quick, relatable scenarios of remote work struggles and how FocusYes can help.
#         *   Example:  A Reel showing someone getting distracted by social media, then using FocusYes to regain focus.
#     *   **Funny/Relatable Skits:**  Short, humorous videos about the realities of working from home.  Subtly mention FocusYes.
#         *   Example: A Reel showing someone trying to attend a meeting while their dog barks incessantly.  Caption: "Remote work life, amirite? 😅 FocusYes helps me stay on task even when chaos ensues!"
#
# *   **Stories:**
#     *   **Polls/Quizzes:**  Interactive polls about remote work habits.
#         *   Example:  "Where do you prefer to work from at home?  A) Dedicated Office B) Couch C) Kitchen Table."
#     *   **Q&A Sessions:**  Use the question sticker to answer user questions about FocusYes.
#     *   **Behind-the-Scenes:**  Share sneak peeks of upcoming features or updates.
#     *   **Countdown Timers:**  For product launches or special offers.
#     *   **Link Stickers:**  (If you have 10K+ followers or an Instagram Business Account) - Directly link to your app store page.  If not, use the "Link in Bio" method.
#     *   **Highlights:** Create highlights for: "Features," "Testimonials," "Tips," "Download," "FAQ".
#
# *   **Carousels:**
#     *   **Step-by-Step Guides:**  Break down complex topics into easily digestible steps.
#         *   Example:  "5 Steps to a More Productive Morning Routine (Even When Working From Home)."
#     *   **Comparison Charts:**  Highlight the benefits of FocusYes compared to other productivity methods.
#         *   Example:  "FocusYes vs. Traditional To-Do Lists: Which is right for you?"
#     *   **List Posts:**  "7 Reasons Why Remote Workers Love FocusYes."
#
# **III.  Captions & Hashtags:**
#
# *   **Captions:**
#     *   **Value-Driven:**  Focus on the benefits for the user (more focus, less procrastination, better time management).
#     *   **Call to Action (CTA):**  Encourage engagement:
#         *   "Download FocusYes today! (Link in bio)"
#         *   "Tell us your biggest remote work struggle in the comments!"
#         *   "Tag a friend who needs to try FocusYes!"
#         *   "What productivity tips work for you?"
#     *   **Use Emojis:**  To add personality and visual appeal.
#     *   **Ask Questions:**  To spark conversation.
#
# *   **Hashtags:**
#     *   **Relevant & Targeted:**
#         *   #remotework #remotejobs #workfromhome #wfh #productivity #timemanagement #focus #procrastination #digitalnomad #softwaredeveloper #projectmanager #remotejobs #remotecompany #distributedteam #worklifebalance #workfromanywhere #remotecommunity #homeoffice #remoteemployee #remoteleadership #focusyes (Your branded hashtag)
#     *   **Mix of Broad & Niche:**
#         *   Don't just use highly competitive hashtags.  Include more specific ones related to your niche.
#     *   **Research Trending Hashtags:**  Keep an eye out for trending hashtags related to remote work and productivity.
#
# **IV.  Engagement & Community Management:**
#
# *   **Respond to Comments & DMs:**  Be active and responsive.
# *   **Like & Comment on Relevant Posts:**  Engage with other accounts in your niche.
# *   **Run Contests/Giveaways:**  Offer free access to FocusYes in exchange for follows, tags, and sharing.
# *   **Partner with Influencers (Micro-Influencers):**  Collaborate with remote work advocates, productivity experts, or influencers in the developer/project manager space.
# *   **Run targeted ads:** The targeting should be based on profession, interest, location.
#
# **V.  App Download Tracking & Feedback Collection:**
#
# *   **Use UTM Parameters:**  When linking to your app store page, use UTM parameters to track where your downloads are coming from (e.g., Instagram post, Instagram story, Instagram ad).
# *   **Promote your in-app feedback mechanisms:** Let people know that you are collecting feedback, and that they have the opportunity to shape the product.
# *   **Monitor App Store Reviews:**  Respond to reviews (positive and negative) to show you're listening.
# *   **Use a Survey Tool:**  Link to a survey (e.g., Google Forms, SurveyMonkey) in your bio or stories to collect more detailed feedback.
#
# **VI. Paid Advertising (Instagram Ads):**
#
# *   **Targeting:**
#     *   **Interests:** Productivity, Time Management, Remote Work, Project Management, Software Development.
#     *   **Behaviors:** Users who have downloaded productivity apps, visited remote work websites, or engaged with content related to these topics.
#     *   **Demographics:** Job titles (Project Manager, Software Engineer, etc.), location (countries with a high concentration of remote workers).
#     *   **Lookalike Audiences:** Create a lookalike audience based on your existing website visitors or app users.
#
# *   **Ad Creative:**
#     *   **Compelling Visuals:** Use high-quality images or videos that showcase the benefits of FocusYes.
#     *   **Strong Headline:** Grab attention with a clear and concise headline (e.g., "Stay Focused While Working Remotely with FocusYes").
#     *   **Benefit-Oriented Copy:** Highlight the key benefits of using FocusYes (e.g., "Boost your productivity, beat procrastination, and achieve your goals").
#     *   **Clear Call to Action:** Use a strong CTA button (e.g., "Download Now," "Learn More," "Try for Free").
#
# *   **Ad Formats:**
#     *   **Image Ads:** Simple and effective for showcasing key features.
#     *   **Video Ads:** Engaging for demonstrating the chatbot in action.
#     *   **Carousel Ads:** Allow you to showcase multiple features or benefits.
#     *   **Stories Ads:** Immersive and can be highly effective for driving app downloads.
#
# **VII. Tracking & Iteration:**
#
# *   **Monitor Your Analytics:**  Pay attention to your follower growth, engagement rates (likes, comments, shares, saves), website clicks, and app downloads.
# *   **A/B Test Your Content:**  Experiment with different types of content, captions, and hashtags to see what resonates best with your audience.
# *   **Adjust Your Strategy:**  Based on your results, adjust your content strategy, targeting, and ad spend accordingly.  Double down on what's working and cut back on what's not.
#
# **Key Takeaways:**
#
# *   **Consistency is Key:**  Post regularly to stay top-of-mind.  Aim for at least 3-5 posts per week.
# *   **Authenticity:**  Be genuine and relatable in your content.
# *   **Community Focus:**  Prioritize building a community around FocusYes.
# *   **Data-Driven Decisions:**  Track your results and use data to inform your strategy.
# *   **Focus on Feedback:** Be receptive to feedback to further improve your product.
# *   **Clear Value Proposition:** Ensure your audience understands *exactly* how FocusYes will improve their remote work life.
#
# By following these steps, you can create a successful Instagram promotion strategy that drives app downloads, gathers valuable feedback, and builds a loyal community of FocusYes users. Good luck!
