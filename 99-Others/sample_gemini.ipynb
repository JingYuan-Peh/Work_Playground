# %%
from google import genai
import os
from dotenv import load_dotenv

# load API keys
load_dotenv()

marketing_prompt = """

You are a smart and friendly assistant.

A user wants help promoting their product. Your task is to collect or infer the following 3 essential details:

1. 🎯 **Target Audience** – Who is this product or service for? 
2. 🛍️ **Product Description** – What is the product?
3. 📈 **Campaign Goals** – What outcome do they want? (e.g., leads, downloads, awareness)

---

**Instructions:**

1. ✅ **Step 1 – Collect info**:  
   - Analyze what the user has already said.
   - If any of the 3 are missing, ask for only the missing parts.
   - Ask 1–2 things per turn. Keep it natural.

2. ✅ **Step 2 – If user give all 3 information**:
   - If all 3 are present (in one go), then perform what the user asked for

3. ✅ **Step 3 – Follow-up questions**:
   - If the user gives a follow-up prompt like:
     - “Can you generate infographics?”
     - “Can you change the tone?”
     - “Now write the caption.”
     - etc.
   - Use the previously gathered product info and last response.
   - Always respond with a helpful tone like a teammate.

---
If the user says something generic like “hi,” start by asking:  
➡️ “Hi! how can I help?”

Always sound warm, proactive, and collaborative.
---


"""
def marketing_handle(query):
    # initialize the model
    client = genai.Client()
    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents = query
    )
    return response.text

    # return {
    #     'statusCode': 200,
    #     'text': response.text
    # }

# %%
query = "Hi, I’m launching a productivity chatbot called FocusYes that helps remote workers stay on task using daily check-ins and gentle nudges. T" \
"he focus group is for remote workers such as developers, project managers. " \
"My main goal is to drive app downloads and get good feedback. i want to post it on Instagram. How should I promote it?"

res = marketing_handle(query)

# %%
print(res)
# Out:
# Okay, let's craft an Instagram strategy to promote FocusYes, targeting remote workers (developers, project managers) and focusing on app downloads and valuable feedback.
#
# **I.  Defining Your Instagram Aesthetic and Tone:**
#
# *   **Aesthetic:**  Clean, modern, tech-forward, and calming. Think blues, greens, and whites. Avoid anything too busy or overwhelming.  Show productive workspaces, clean interfaces, and visually appealing charts/graphs that hint at increased productivity.
# *   **Tone:**  Helpful, encouraging, understanding, and slightly humorous.  You understand the struggles of remote work and offer a solution without being preachy.
#
# **II. Content Pillars (Recurring Themes):**
#
# These are the core topics you'll consistently create content around.
#
# *   **#RemoteWorkLife:** Showcasing the realities, challenges, and benefits of remote work.
# *   **#ProductivityHacks:** Quick tips, tools, and strategies to boost focus and efficiency.
# *   **#FocusYesFeatures:**  Highlighting specific features of your chatbot and demonstrating how they solve common productivity problems.
# *   **#UserSuccessStories:**  Testimonials and results from real FocusYes users.
# *   **#BehindTheScenes:**  Give a glimpse into the making of FocusYes, the team behind it, and the culture.
# *   **#InteractiveEngagement:** Posing questions, polls, and challenges to engage your audience.
#
# **III.  Types of Content:**
#
# Here’s a breakdown of content types and examples:
#
# *   **Image Posts:**
#     *   **Quotes:**  Inspirational quotes about focus, productivity, and remote work.  Example: "The key is not to prioritize what's on your schedule, but to schedule your priorities." - Stephen Covey.  Use visually appealing graphics with your brand colors.
#     *   **Infographics:** Simple, digestible infographics that explain productivity concepts or highlight key statistics about remote work challenges.  Example: "The Pomodoro Technique Explained" or "5 Common Remote Work Distractions (and How to Beat Them)".
#     *   **Workspace Inspiration:**  Show aesthetically pleasing and functional remote workspaces.  Feature user-submitted workspaces (with permission) if possible.  Use high-quality photos.
#     *   **FocusYes Screenshots:**  Show the chatbot interface, highlighting its ease of use and key features.  Annotate the screenshots with text to explain what's happening.
#     *   **"Did You Know?" Facts:**  Share interesting facts related to productivity, focus, or remote work.  Example: "Did you know that multitasking can decrease productivity by as much as 40%?"
#
# *   **Video Posts (Reels and Regular Posts):**
#     *   **Demo Videos:** Short, snappy videos (15-30 seconds) showcasing FocusYes in action. Show how it can be used to tackle real remote work challenges.
#     *   **"A Day in the Life" Vlogs:** Follow a remote worker using FocusYes to stay productive throughout the day.
#     *   **Tutorials:**  Quick tutorials on how to use specific FocusYes features.
#     *   **Talking Head Videos:**  Founder/team members talking about the benefits of FocusYes, addressing common pain points, or sharing productivity tips.  Keep these short and engaging.
#     *   **Behind-the-Scenes:** Glimpses into the development of FocusYes.
#     *   **User Testimonials:**  Short video clips of users sharing their positive experiences with FocusYes.
#
# *   **Stories:**
#     *   **Polls and Quizzes:**  "What's your biggest remote work struggle?" or "What type of remote worker are you?" (with results linking to FocusYes features).
#     *   **Q&A Sessions:**  Answer questions about FocusYes and remote work.
#     *   **Countdown Timers:**  Announce upcoming features, updates, or promotions.
#     *   **Behind-the-Scenes:**  Share informal, authentic moments from the team.
#     *   **Link Stickers:** Use these to drive traffic directly to your app download page.
#     *   **Interactive Stickers:** Use question stickers to gather feedback on desired features.
#     *   **"This or That" Templates:**  Example: "Coffee or Tea? Quiet or Music while working?"  Relatable and engaging.
#
# *   **Instagram Live:**
#     *   **Live Q&A Sessions:**  With the founder, product manager, or productivity expert.
#     *   **Product Demos:**  Showcase FocusYes in real-time and answer questions live.
#     *   **Guest Interviews:**  Invite other remote work influencers or experts for discussions.
#
# *   **Instagram Ads:**
#     *   **Targeting:**  Use Instagram's targeting options to reach your ideal audience:
#         *   **Interests:** Productivity, remote work, project management, software development, technology.
#         *   **Demographics:**  Age, location (consider areas with high concentrations of tech workers).
#         *   **Behaviors:**  Users who are likely to download apps, interested in business tools, etc.
#     *   **Ad Formats:**
#         *   **Image Ads:**  Use compelling images with clear calls to action ("Download Now!").
#         *   **Video Ads:**  Short, engaging videos showcasing FocusYes.
#         *   **Carousel Ads:**  Highlight multiple features of FocusYes.
#         *   **Story Ads:**  Full-screen ads that appear between users' Stories.
#
# **IV.  Call to Action (CTA):**
#
# Every post should have a clear CTA.  Make it easy for people to take the next step.
#
# *   **"Download FocusYes Now! (Link in Bio)"** (Use a link shortener like Bitly to track clicks).
# *   **"Try FocusYes for Free! (Link in Bio)"** (If you offer a free trial).
# *   **"Learn More About FocusYes (Link in Bio)"** (Link to your website or landing page).
# *   **"Share Your Remote Work Struggles in the Comments!"** (Encourage engagement).
# *   **"What features would you like to see in the app? Let us know in the comments."** (Gather feedback)
# *   **"Tag a friend who struggles with productivity!"**
# *   **"Rate FocusYes on the App Store/Google Play Store (Link in Bio)"**
#
# **V.  Hashtags:**
#
# Use a mix of broad and specific hashtags to increase visibility.  Research relevant hashtags.
#
# *   **Broad:** #remotework #remotejobs #workfromhome #productivity #productivityhacks #timemanagement #focus #wfh #digitalnomad
# *   **Specific:** #focusyes #productivitychatbot #remotecontrol #remoteteam #developerproductivity #projectmanagementtools
# *   **Branded:** #focusyesapp (Create a unique hashtag for your brand).
#
# **VI.  Engagement Strategy:**
#
# *   **Respond to Comments and DMs:**  Be responsive and helpful.
# *   **Like and Comment on Relevant Posts:**  Engage with other accounts in your niche.
# *   **Run Contests and Giveaways:**  Offer a free subscription or other incentives.  "Tag two friends and follow us for a chance to win a free year of FocusYes!"
# *   **Collaborate with Influencers:**  Partner with remote work influencers or productivity experts.  Send them a free trial of FocusYes and ask them to review it.
# *   **Run Polls:** Encourage people to get involved and show how FocusYes can help.
#
# **VII. Measuring Results and Iterating:**
#
# *   **Track Key Metrics:**
#     *   **Follower Growth:** Are you attracting new followers?
#     *   **Engagement Rate:**  Likes, comments, shares, saves.
#     *   **Website Clicks:**  How many people are clicking the link in your bio?
#     *   **App Downloads:**  Track downloads from Instagram referral traffic.
#     *   **Feedback:**  Monitor comments, DMs, and app store reviews for user feedback.
# *   **Analyze Data:**  Use Instagram Insights to understand what content is performing well and what isn't.
# *   **Adjust Strategy:**  Based on your results, adjust your content, hashtags, and targeting. Double down on what's working and eliminate what isn't.
#
# **VIII. Important Considerations:**
#
# *   **Consistency is Key:** Post regularly (at least 3-5 times per week).  Use a social media scheduling tool to plan and automate your posts.
# *   **High-Quality Visuals:**  Use professional-looking photos and videos.
# *   **Authenticity:**  Be genuine and relatable.  Don't try to be someone you're not.
# *   **Compliance:** Be mindful of Instagram's community guidelines and advertising policies.
# *   **Landing Page Optimization:** Make sure the landing page your Instagram bio links to is optimized for conversions (clear CTA, easy to download the app).
# *   **A/B Testing:** If you're running ads, A/B test different ad creatives, copy, and targeting options to see what performs best.
#
# **Example Campaign Outline (First Two Weeks):**
#
# *   **Week 1: Introduction and Problem Awareness**
#     *   Post 1: Image: Inspirational quote about focus. Caption: "Struggling to stay on task while working from home? You're not alone. Let us know your biggest time-wasting habit in the comments! #remotework #productivity #focus"
#     *   Post 2: Video (Reel): Short demo showing how FocusYes can block distracting websites. Caption: "Say goodbye to endless social media scrolling! FocusYes helps you stay on track. Download now (Link in Bio)! #focusyes #productivitychatbot"
#     *   Post 3: Image: Infographic: "3 Common Remote Work Productivity Killers". Caption: "Learn how to overcome these distractions and get more done. #remoteworklife #productivityhacks"
#     *   Story: Poll: "What distracts you most at home?" (Options: Social Media, Family, House Chores, Netflix) with Link sticker to download the app.
#     *   AD Campaign: Image Ad:  Problem-focused ad targeting users interested in remote work, highlighting the struggle with distractions.
# *   **Week 2: Feature Highlights and User Benefits**
#     *   Post 4: Image: Screenshot of FocusYes interface. Caption: "FocusYes makes it easy to set daily goals and track your progress. Get a gentle nudge when you start to stray. Try it free (link in bio)"
#     *   Post 5: Video (Reel): Short user testimonial. Caption: "FocusYes has been a game-changer for my productivity! - [User Name]. Download today!"
#     *   Post 6: Image: Quote from the App Store review. Caption: "See what our users are saying about FocusYes! [Link to download].
#     *   Story: Q&A: Answer questions about how FocusYes works.
#     *   AD Campaign: Video Ad showing the main features and benefits of FocusYes.
#
# By following these strategies, you can effectively promote FocusYes on Instagram, drive app downloads, and gather valuable feedback from your target audience. Good luck!
